# %% [markdown]
# <a href="https://colab.research.google.com/github/gouthami2309/house_sales/blob/main/House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X= data.drop(['median_house_value'],axis= 1)
y = data['median_house_value']

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2)

# %%
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3942     -118.60     34.21                21.0       9512.0          2560.0
# 1551     -121.94     37.75                16.0       5121.0           735.0
# 5994     -117.72     34.09                33.0       4979.0           934.0
# 20310    -119.14     34.17                16.0       1593.0           353.0
# 19730    -121.51     38.79                29.0       1716.0           323.0
# ...          ...       ...                 ...          ...             ...
# 19966    -119.08     36.21                20.0       1911.0           389.0
# 7787     -118.06     33.90                37.0       1161.0           254.0
# 13573    -117.29     34.14                45.0       1598.0           314.0
# 8137     -118.13     33.83                45.0       3087.0           574.0
# 20501    -118.71     34.30                20.0       1586.0           187.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation calculation
numeric_data = train_data.select_dtypes(include=[np.number])

# Set up the matplotlib figure
plt.figure(figsize=(15, 8))

# Create a heatmap of the correlation matrix
sns.heatmap(numeric_data.corr(), annot=True, cmap='YlGnBu', linewidths=0.5)

# Display the plot
plt.show()

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
numeric_data = train_data.select_dtypes(include=[np.number])
correlation_matrix = numeric_data.corr()
print(correlation_matrix)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923962           -0.109348     0.031355
# latitude            -0.923962  1.000000            0.011058    -0.033032
# housing_median_age  -0.109348  0.011058            1.000000    -0.316143
# total_rooms          0.031355 -0.033032           -0.316143     1.000000
# total_bedrooms       0.063430 -0.069914           -0.273290     0.945951
# population           0.111074 -0.137598           -0.243158     0.861360
# households           0.058322 -0.090023           -0.241481     0.931182
# median_income       -0.016859 -0.077596           -0.120189     0.206900
# median_house_value  -0.048178 -0.141295            0.104018     0.161083
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063430    0.111074    0.058322      -0.016859
# latitude                 -0.069914   -0.137598   -0.090023      -0.077596
# ...

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7189
# INLAND        5207
# NEAR OCEAN    2107
# NEAR BAY      1840
# ISLAND           3
# Name: count, dtype: int64

# %%
import pandas as pd

# Generate dummy variables for 'ocean_proximity' and convert to integers
ocean_proximity_dummies = pd.get_dummies(train_data.ocean_proximity).astype(int)

# Join the dummy variables to the original DataFrame and drop the original 'ocean_proximity' column
train_data = train_data.join(ocean_proximity_dummies).drop(['ocean_proximity'], axis=1)

# Display the first few rows of the updated DataFrame
print(train_data.head())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3942     -118.60     34.21                21.0     9.160415        7.848153
# 1551     -121.94     37.75                16.0     8.541300        6.601230
# 5994     -117.72     34.09                33.0     8.513185        6.840547
# 20310    -119.14     34.17                16.0     7.374002        5.869297
# 19730    -121.51     38.79                29.0     7.448334        5.780744
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3942     8.893298    7.778211         2.8039            227500.0          1
# 1551     7.809947    6.635947         6.6204            296100.0          1
# 5994     7.853993    6.774224         3.7958            152500.0          0
# 20310    6.729824    5.880533         2.7260             67500.0          0
# 19730    6.746412    5.645447         2.9324            137500.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
plt.figure(figsize=(15, 8))

# Create a heatmap of the correlation matrix
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/ train_data['total_rooms']
train_data['household_rooms']=train_data['total_rooms']/ train_data['households']

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train,y_train = train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

# Generate dummy variables for 'ocean_proximity' and convert to integers
ocean_proximity_dummies = pd.get_dummies(test_data.ocean_proximity).astype(int)

# Join the dummy variables to the original DataFrame and drop the original 'ocean_proximity' column
test_data = test_data.join(ocean_proximity_dummies).drop(['ocean_proximity'], axis=1)

# Display the first few rows of the updated DataFrame
print(test_data.head())

test_data['bedroom_ratio']=test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/ test_data['households']
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12210    -116.96     33.62                 8.0     6.911747        5.123964
# 17702    -121.83     37.32                17.0     7.543273        6.499787
# 7895     -118.08     33.85                19.0     8.357494        6.520621
# 14864    -117.09     32.64                38.0     7.647786        6.285998
# 7891     -118.07     33.88                17.0     7.786552        6.291569
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12210    5.963579    4.948760         4.2917            221900.0          0
# 17702    7.553287    6.393591         2.5652            165300.0          1
# 7895     7.871693    6.495266         6.2427            288700.0          1
# 14864    7.123673    6.311735         2.7218            145900.0          0
# 7891     7.260523    6.263398         4.2619            139700.0          1
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3942     -118.60     34.21                21.0     9.160415        7.848153
# 1551     -121.94     37.75                16.0     8.541300        6.601230
# 5994     -117.72     34.09                33.0     8.513185        6.840547
# 20310    -119.14     34.17                16.0     7.374002        5.869297
# 19730    -121.51     38.79                29.0     7.448334        5.780744
# ...          ...       ...                 ...          ...             ...
# 19966    -119.08     36.21                20.0     7.555905        5.966147
# 7787     -118.06     33.90                37.0     7.057898        5.541264
# 13573    -117.29     34.14                45.0     7.377134        5.752573
# 8137     -118.13     33.83                45.0     8.035279        6.354370
# 20501    -118.71     34.30                20.0     7.369601        5.236442
#
# ...

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12210    -116.96     33.62                 8.0     6.911747        5.123964
# 17702    -121.83     37.32                17.0     7.543273        6.499787
# 7895     -118.08     33.85                19.0     8.357494        6.520621
# 14864    -117.09     32.64                38.0     7.647786        6.285998
# 7891     -118.07     33.88                17.0     7.786552        6.291569
# ...          ...       ...                 ...          ...             ...
# 4389     -118.26     34.07                36.0     7.743703        6.701960
# 10549    -117.77     33.70                 4.0     7.802618        6.434547
# 2257     -119.84     36.80                19.0     8.084871        6.655440
# 3665     -118.37     34.22                17.0     7.488853        6.139885
# 1111     -121.60     39.79                18.0     7.890957        6.280396
#
# ...

# %%
X_test,y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
reg.score(X_test,y_test)
# Out:
# 0.6786830581603551

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5573e33875d> in <cell line: 3>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 forest = RandomForestRegressor()
# ----> 3 forest.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %%
forest.score(X_test,y_test)
# Out:
# 0.8235235582628041

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],  # Corrected parameter name
    "max_depth": [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",  # Corrected spelling
                           return_train_score=True)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Assuming X_train and y_train are already defined
forest = RandomForestRegressor(n_estimators=5, min_samples_split=2, max_depth=None, random_state=42)
forest.fit(X_train, y_train)

# Extract one tree from the forest
tree = forest.estimators_[0]

# Visualize the tree
plt.figure(figsize=(20, 10))
plot_tree(tree, feature_names=X_train.columns, filled=True, rounded=True)
plt.show()
